# %% [markdown]
# ![image.png](attachment:41179301-0d23-45ae-9416-92e00ae1479e.png)

# %% [markdown]
# ![image.png](attachment:0e248f12-aacf-40a9-9d8c-efb2fb450e95.png)

# %% [markdown]
# ![image.png](attachment:2358524f-2b0a-4710-9c43-c405a37a83d2.png)

# %% [markdown]
# ![image.png](attachment:0d67c196-2f67-452c-a5a0-4657298f1d3e.png)

# %% [markdown]
# ![image.png](attachment:5b374d0c-0cec-4948-a4bc-73df614d4ad4.png)

# %% [markdown]
# ![image.png](attachment:0517e446-d1c2-4080-8466-680eafc2e632.png)

# %% [markdown]
# ![image.png](attachment:3ecfb26c-885d-4edb-a78c-c7beedc1dd9c.png)

# %% [markdown]
# ![image.png](attachment:1f3e7250-666d-46c2-92ae-eb79fda2fab5.png)

# %% [markdown]
# ![image.png](attachment:b14ed793-38b6-44ef-b52f-034365df5462.png)

# %% [markdown]
# ![image.png](attachment:9982c127-a102-444b-8fa2-75e89bc8bfe2.png)
